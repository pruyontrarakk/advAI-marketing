# %%
def generate_ad(product, audience, style):

    query=f"""
Find similar ads for {product}
target audience {audience}
style {style}
"""

    context = retrieve_ads(query)

    prompt=f"""
You are an expert ad copywriter.

Based on these ads:
{context}

Create a new advertisement.

Product: {product}
Audience: {audience}
Style: {style}

Generate:

1 Headline
2 Body copy
3 CTA
"""

    return qwen_generate(prompt)
