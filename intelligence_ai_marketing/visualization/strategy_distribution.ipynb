# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("data/ads_master_dataset.csv")

counts=df["strategy"].value_counts()

plt.figure()

counts.plot(kind="bar")

plt.title("Distribution of Advertising Strategies")

plt.xlabel("Strategy")

plt.ylabel("Number of Ads")

plt.show()
