# %%
# !touch "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/pipeline/__init__.py"
# !touch "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/cv/__init__.py"
# !touch "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/nlp/__init__.py"
# !touch "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/clustering/__init__.py"
# !touch "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/database/__init__.py"

# %%
import sys
import os

from google.colab import drive
drive.mount("/content/drive", force_remount=True)


PROJECT_ROOT = "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing"

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(sys.path[:3])
# !ls "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing"
# Out:
# Mounted at /content/drive
# ['/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing', '/content', '/env/python']
# analytics   cv	  database    nlp	rag  visualization
# clustering  data  evaluation  pipeline	ui

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/nlp/analyze_image_text.py"
# !python "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/clustering/updated_strategy_clustering.py"
# !python "/content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/database/data_store.py"
# Out:
# Computing keywords (TF-IDF)...
# Saved 2872 rows to /content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/data/image_text_analysis.csv
# Running strategy clustering...
# Rows after cleaning: 2046
# Columns:
# Index(['ad_id', 'json_key', 'image_path', 'competitor', 'all_categories',
#        'all_categories_full', 'all_sentiments', 'all_sentiments_full',
#        'objects_symbols', 'image_width', 'image_height', 'image_format',
#        'ocr_text', 'ocr_word_count', 'ocr_confidence_avg', 'text_area_px',
#        'image_area_px', 'text_image_ratio', 'layout_type', 'dominant_color_1',
#        'dominant_color_2', 'dominant_color_3', 'dominant_color_4',
#        'dominant_color_5', 'color_palette_json', 'extraction_status',
#        'sentiment_polarity', 'sentiment_subjectivity', 'top_words',
#        'top_keywords'],
#       dtype='object')
# Feature matrix shape: (2046, 52)
# Silhouette score: 0.12244848963679296
#
# Cluster 0
# 0       flavors|fine|eating
# 1        making|place|thing
# 6           living|home|www
# 8              sweet|hot|et
# 19         free|fat|flavors
# 25         plans|mobile|win
# 26        friends|good|time
# 31    caramel|vanilla|brand
# 33                      eat
# 35     needs|feel|beautiful
# Name: top_keywords, dtype: object
#
# Sample OCR text:
#                                             ocr_text
# 0  For she's eating Necco Wafers. COOL, CRISP, RE...
# 1  HEY YOU ABOUT TO USE COMIC SANS FOR THAT THING...
# 6  WELCOME TO MY LIVING ROOM / f | \ \ WWW.BASKIN...
#
# Cluster 1
# 3           hot|2013|black
# 5     finance|available|uk
# 7       power|energy|needs
# 10    oreo|celebrate|young
# 13          sale|shop|save
# 18        skin|cream|young
# 27       pure|long|perfect
# 34              bad|change
# 41     school|talk|friends
# 42          test|drive|new
# Name: top_keywords, dtype: object
#
# Sample OCR text:
#                                             ocr_text
# 3    Black Walmart  How to understand this HOT event
# 5  iii WE CELEBRATING ) MI ‘nat Ate YEARS IN THE ...
# 7  ) The Greenest Power Is Power Not Used. requir...
#
# Cluster 2
# 16      nissan|dealer|local
# 53        happy|nissan|year
# 98               fun|nissan
# 108             2013|nissan
# 121             2013|nissan
# 221            la|se|nissan
# 228            built|nissan
# 295    available|nissan|new
# 320     nissan|excites|hard
# 409    cars|ask|information
# Name: top_keywords, dtype: object
#
# Sample OCR text:
#                                              ocr_text
# 16  aw Nissan JUKE, voted Continental. Car of the ...
# 53  Tan Chong and Nissan wishes you a HAPPY and PR...
# 98                NISSAN NAVARA MORE CAPACITY FOR FUN
#
# Cluster 3
# 2                    let|20|know
# 4                control|com|000
# 9                 text|drive|don
# 11                    helps|text
# 12                         00|al
# 14                      sandwich
# 15    cancer|smoking|information
# 17           smoking|cancer|need
# 20              children|million
# 21                    care|heart
# Name: top_keywords, dtype: object
#
# Sample OCR text:
#                                             ocr_text
# 2  Let ‘em know youre SD JOCKEY. POUCH Firefighte...
# 4  Direccion hidraulica Volante de direccion regu...
# 9     Enter Passcode Emergency DON’T TEXT AND DRIVE.
#
# Saved clustered dataset to: /content/drive/MyDrive/Colab Notebooks/intelligence_ai_marketing/data/ads_with_strategies.csv
#
# === Demo outputs ===
# chocolate frequently uses Public Awareness, Safety & Social Impact
# chips ads primarily use: Food, Lifestyle & Consumer Branding
# safety ads primarily use: Public Awareness, Safety & Social Impact
# beauty ads primarily use: Retail, Utility & Promotional Messaging
# beauty ads primarily use: Retail, Utility & Promotional Messaging
# Suggested move: Compete with premium positioning.
#
# Unique industries:
# ['chips' 'media' 'clothing' 'shopping' 'cars' 'chocolate' 'environment'
#  'human_right' 'financial' 'restaurant' 'smoking_alcohol_abuse' 'beauty'
#  'domestic_violence' 'healthcare' 'safety' 'phone_tv_internet_providers'
#  'coffee' 'soda' 'animal_right' 'self_esteem' 'topic_girl scouts'
#  'software' 'travel' 'topic_Pepperidge Farm Bread' 'alcohol' 'electronics'
#  'cleaning' 'other_service' 'baby' 'charities' 'seasoning' 'sports'
#  'home_appliance' 'topic_Sex education advocacy' 'topic_jewelry'
#  'topic_guns' 'topic_Baking, sugar'
#  'topic_health-related public service announcement' 'topic_Food'
#  'topic_Condom use advocacy' 'topic_adoption' 'topic_Fabrics & DIY' 'game'
#  'topic_tampons' 'topic_Anti-Fat' 'education' 'political' 'topic_Tobacco'
#  'topic_Bread, food' 'home_improvement']
# Database created with 2046 ads
