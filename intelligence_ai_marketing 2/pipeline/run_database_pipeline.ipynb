# %%
from database.data_store import fill_database

def run_database():

    print("STEP 5: Building SQLite database")

    fill_database()

    print("Database ready")


if __name__ == "__main__":
    run_database()
