# %%
from cv.data_collect import collect

def run_data_collection():

    print("STEP 1: Collecting ads from annotations")

    collect()

    print("Data collection finished")


if __name__ == "__main__":
    run_data_collection()
