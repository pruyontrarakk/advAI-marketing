# %%
from cv.extraction import extract_all

def run_cv():

    print("STEP 2: Running CV feature extraction")

    extract_all()

    print("CV extraction finished")


if __name__ == "__main__":
    run_cv()
