# %%
from clustering.updated_strategy_clustering import run_clustering

def run_cluster():

    print("STEP 4: Running strategy clustering")

    run_clustering()

    print("Clustering finished")


if __name__ == "__main__":
    run_cluster()
