# %%
from nlp.analyze_image_text import main as run_nlp

def run_nlp_pipeline():

    print("STEP 3: Running NLP analysis")

    run_nlp()

    print("NLP analysis finished")


if __name__ == "__main__":
    run_nlp_pipeline()
