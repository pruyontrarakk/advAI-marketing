# %%
questions=[
"Which strategies dominate retail ads?",
"Which industries use emotional messaging?",
]

for q in questions:
    print(rag_query(q))

# %% [markdown]
# human evaluate ai outputted answer and devide if it is an ai agent up to the stansard of a marketing strategist or their assistant
